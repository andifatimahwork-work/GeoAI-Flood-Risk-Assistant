# %% [markdown]
# # 01b EDA Sebelum Training
#
# Notebook ini menjalankan EDA setelah preprocessing dan sebelum training U-Net.

# %%
from pathlib import Path
import sys

PROJECT_DIR = Path(r"E:\\AI ML\\GeoAI_Flood_Susceptibility")
sys.path.insert(0, str(PROJECT_DIR / "src"))
print(PROJECT_DIR)

# %%
from geoai_flood.config import load_config
from geoai_flood.eda import run_eda

cfg = load_config(PROJECT_DIR / "config" / "config.yaml")
out_dir = run_eda(cfg)
out_dir

# %% [markdown]
# Output utama:
#
# - `outputs/eda/class_distribution.png`
# - `outputs/eda/class_weights.json`
# - `outputs/eda/bad_tiles.txt`
# - `outputs/eda/dataset_stats_clipped.json`
# - `outputs/eda/dominant_class_split_summary.csv`
# - `outputs/eda/eda_warnings.txt`
# - `outputs/eda/band_stats_plot.png`
# - `outputs/eda/sample_visual_inspection.png`
# - `outputs/eda/red_nir_scatter.png`
# - `outputs/tiles/train_list_clean.txt`
# - `outputs/tiles/val_list_clean.txt`
